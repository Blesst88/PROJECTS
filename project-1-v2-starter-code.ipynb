# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 15px; height: 80px">
#
# # Project 1
#
# ### Building "Pokemon Stay"
#
# ---
# You are an analyst at a "scrappy" online gaming company that specializes in remakes of last year's fads.
#
# Your boss, who runs the product development team, is convinced that Pokemon Go's fatal flaw was that you had to actually move around outside. She has design mock-ups for a new game called Pokemon Stay: in this version players still need to move, but just from website to website. Pokemon gyms are now popular online destinations, and catching Pokemon in the "wild" simply requires browsing the internet for hours in the comfort of your home.
#
# She wants you to program a prototype version of the game, and analyze the planned content to help the team calibrate the design.

# %% [markdown]
# #### Package imports
#
# The pprint package below is the only package imported here, and it's not even strictly required to do any of the project. Printing python variables and objects with pprint can help to format them in a "prettier" way.

# %%
from pprint import pprint

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 1. Defining a player
#
# ---
#
# The player variables are:
#
#     player_id : id code unique to each player (integer)
#     player_name : entered name of the player (string)
#     time_played : number of time played the game in minutes (float)
#     player_pokemon: the player's captured pokemon (dictionary)
#     gyms_visited: ids of the gyms that a player has visited (list)
#
# Create the components for a player object by defining each of these variables. The dictionary and list variables should just be defined as empty; you can use any (correctly typed) values for the others.

# %%
player_id =1
player_name='Ben'
time_played=float(10)
player_pokemon={}
gyms_visited=[]
player_desc=['player_id','player_name','time_played','player_pokemon','gyms_visited']
player_desc_val=[player_id,player_name,time_played,player_pokemon,gyms_visited]
player_desc,player_desc_val
# Out:
# (['player_id', 'player_name', 'time_played', 'player_pokemon', 'gyms_visited'],
#  [1, 'Ben', 10.0, {}, []])

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 2. Defining "gym" locations
#
# ---
#
# As the sole programmer, Pokemon Stay will have to start small. To begin, there will be 10 different gym location websites on the internet. The gym locations are:
#
#     1. 'reddit.com'
#     2. 'amazon.com'
#     3. 'twitter.com'
#     4. 'linkedin.com'
#     5. 'ebay.com'
#     6. 'netflix.com'
#     7. 'sporcle.com'
#     8. 'stackoverflow.com'
#     9. 'github.com'
#     10. 'quora.com'
#
# 1. Set up a list of all the gym locations. This will be a list of strings.
# 2. Append two of these locations to your player's list of visited gyms.
# 3. Print the list.

# %%
gym_loc=[]

gym_loc=['reddit.com','amazon.com','twitter.com','linkedin.com','ebay.com','netflix.com','sporcle.com','stackoverflow.com', 
'github.com','quora.com']

gym_loc
# Out:
# ['reddit.com',
#  'amazon.com',
#  'twitter.com',
#  'linkedin.com',
#  'ebay.com',
#  'netflix.com',
#  'sporcle.com',
#  'stackoverflow.com',
#  'github.com',
#  'quora.com']

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 3. Create a pokedex
#
# ---
#
# We also need to create some pokemon to catch. Each pokemon will be defined by these variables:
#
#     pokemon_id : unique identifier for each pokemon (integer)
#     name : the name of the pokemon (string)
#     type : the category of pokemon (string)
#     hp : base hitpoints (integer)
#     attack : base attack (integer)
#     defense : base defense (integer)
#     special_attack : base special attack (integer)
#     special_defense : base sepecial defense (integer)
#     speed : base speed (integer)
#
# We are only going to create 3 different pokemon with these `pokemon_id` and `pokemon_name` values:
#
#     1 : 'charmander'
#     2 : 'squirtle'
#     3 : 'bulbasaur'
#
# Create a dictionary that will contain the pokemon. The keys of the dictionary will be the `pokemon_id` and the values will themselves dictionaries that contain the other pokemon variables. The structure of the pokedex dictionary will start like so:
#
#      {
#          1: {
#                  'name':'charmander',
#                  'type':'fire',
#                  ...
#
# The `type` of charmander, squirtle, and bulbasaur should be `'fire'`, `'water'`, and `'poison'` respectively. The other values are up to you, make them anything you like!
#
# Print (or pretty print) the pokedex dictionary with the 3 pokemon.

# %%
pokemon_id=0
name=''
type=''
hp=0
attack=0
defense=0
special_attack=0
special_defense=0
speed=0

pokedex={1.0 : {'name':'charmander', 'type':'fire','hp':101 ,'attack':102,'defense':103, 'special_attack':104,'special_defense':105,'speed':106},
              2.0 : {'name':'squirtle', 'type':'water','hp':201 ,'attack':202,'defense':203, 'special_attack':204,'special_defense':205,'speed':206},
              3.0 : {'name':'bulbasaur', 'type':'poison','hp':301 ,'attack':302,'defense':303, 'special_attack':304,'special_defense':305,'speed':306
                  }}
pokedex
# Out:
# {1.0: {'attack': 102,
#   'defense': 103,
#   'hp': 101,
#   'name': 'charmander',
#   'special_attack': 104,
#   'special_defense': 105,
#   'speed': 106,
#   'type': 'fire'},
#  2.0: {'attack': 202,
#   'defense': 203,
#   'hp': 201,
#   'name': 'squirtle',
#   'special_attack': 204,
#   'special_defense': 205,
#   'speed': 206,
#   'type': 'water'},
#  3.0: {'attack': 302,
#   'defense': 303,
#   'hp': 301,
#   'name': 'bulbasaur',
#   'special_attack': 304,
#   'special_defense': 305,
#   'speed': 306,
#   'type': 'poison'}}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 4. Create a data structure for players
#
# ---
#
# ### 4.1
#
# In order to maintain a database of multiple players, create a dictionary that keeps track of players indexed by `player_id`.
#
# The keys of the dictionary will be `player_id` and values will be dictionaries containing each player's variables (from question 1).
#
# Construct the `players` dictionary and insert the player that you defined in question 1, then print `players`.

# %%
players={}

# players1={'player_id':{'player_id':1,'player_name':'Ben','time_played':float(10),'player_pokemon':{},'gyms_visited':[]}}
# players2={1:{'player_name':'Ben','time_played':float(10),'player_pokemon':{},'gyms_visited':[]}}
players[1] = {'player_name':'Ben','time_played':float(10),'player_pokemon':{},'gyms_visited':[]}

# %%
players
# Out:
# {1: {'gyms_visited': [],
#   'player_name': 'Ben',
#   'player_pokemon': {},
#   'time_played': 10.0}}

# %% [markdown]
# ---
#
# ### 4.2
#
# Create a new player with `player_id = 2` in the `players` dictionary. Leave the `'player_pokemon'` dictionary empty. Append `'alcatraz'` and `'pacific_beach'` to the `'gyms_visited'` list for player 2.
#
# The `'player_name'` and `'time_played'` values are up to you, but must be a string and float, respectively.
#
# Remember, the player_id is the key for the player in the players dictionary.
#
# Print the `players` dictionary with the new player inserted.

# %%
new_player={}
new_player= {'player_name':'Judy','time_played':float(20),'player_pokemon':{},'gyms_visited':['alactraz','pacific_beach']}

players[2]=new_player
players

players[1]['gyms_visited'] = ['amazon.com']

players
# Out:
# {1: {'gyms_visited': ['amazon.com'],
#   'player_name': 'Ben',
#   'player_pokemon': {},
#   'time_played': 10.0},
#  2: {'gyms_visited': ['alactraz', 'pacific_beach'],
#   'player_name': 'Judy',
#   'player_pokemon': {},
#   'time_played': 20.0}}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 5. Add captured pokemon for each player
#
# ---
#
# The `'player_pokemon'` keyed dictionaries for each player keep track of which of the pokemon each player has.
#
# The keys of the `'player_pokemon'` dictionaries are the pokemon ids that correspond to the ids in the `pokedex` dictionary you created earlier. The values are integers specifying the stats for the pokemon.
#
# Give player 1 a squirtle. Give player 2 charmander and a bulbasaur.
#
# Print the players dictionary after adding the pokemon for each player.

# %%
players[1] = {'player_name':'Ben','time_played':float(10),'player_pokemon':{},'gyms_visited':[]}  
players[1]['gyms_visited'] = ['amazon.com']
player_pokemon={}
player_pokemon[1]={'stats':100}
player_pokemon[2]={'stats':200}

player_pokemon
# Out:
# {1: {'stats': 100}, 2: {'stats': 200}}

# %%
# players[2]['gyms_visited'] = ['gym1']

players[1]['player_pokemon']=['squirtle']
players[2]['player_pokemon']=['charmander','bulbasaur']
print players
# Out:
# {1: {'time_played': 10.0, 'gyms_visited': ['amazon.com'], 'player_name': 'Ben', 'player_pokemon': ['squirtle']}, 2: {'time_played': 20.0, 'gyms_visited': ['alactraz', 'pacific_beach'], 'player_name': 'Judy', 'player_pokemon': ['charmander', 'bulbasaur']}}

# %% [markdown]
# ## 6. What gyms have players visited?
#
# ---
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
# ### 6.1
#
# Write a for-loop that:
#
# 1. Iterates through the `pokemon_gyms` list of gym locations you defined before.
# 2. For each gym, iterate through each player in the `players` dictionary with a second, internal for-loop.
# 3. If the player has visited the gym, print out "[player] has visited [gym location].", filling in [player] and [gym location] with the current player's name and current gym location.

# %%
count=0
for gym in gym_loc:
      for player in players:
              if gym in players[player]['gyms_visited']:
                    count=count+1
                    print 'player has visited', gym
                    print count
# Out:
# player has visited amazon.com
# 1

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
# ### 6.2
#
# How many times did that loop run? If you have N gyms and also N players, how many times would it run as a function of N?
#
# Can you think of a more efficient way to accomplish the same thing?
#
# (You can write your answer as Markdown text.)

# %%
# 10 * 2 as there are 10 locations with 2 players
# N * N or less

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 7. Calculate player "power".
#
# ---
#
# Define a function that will calculate a player's "power". Player power is defined as the sum of the base statistics all of their pokemon.
#
# Your function will:
#
# 1. Accept the `players` dictionary, `pokedex` dictionary, and a player_id as arguments.
# 2. For the specified player_id, look up that player's pokemon and their level(s).
# 3. Find and aggregate the attack and defense values for each of the player's pokemon from the `pokedex` dictionary.
# 4. Print "[player name]'s power is [player power].", where the player power is the sum of the base statistics for all of their pokemon.
# 5. Return the player's power value.
#
# Print out the pokemon power for each of your players.

# %%
def players_power(players_dict,pokedex_dict,whoplayer):
    print 'whoplayer: ' ,whoplayer
    player_power=0
    for key in players_dict.keys():   
#       for idx, val in enumerate(players_dict[key]):
#                  print(idx, val), 'whoplayer', whoplayer
        if key==whoplayer:
# now lookup pokemon stats level 
          for key2 in player_pokemon.keys():
              if key==key2:
                 print 'key2', key2
                 print  'stats:-', player_pokemon[key2]['stats']
# now lookup pokedex defense and attack stats 
              for key3 in pokedex_dict.keys():
                    if key==key3:
                       print 'key3',key3
                       print  'attack:-', pokedex_dict[key3]['attack']
                       print  'defense:-', pokedex_dict[key3]['defense']
# calculate power = sum of all 6 base values and print                         
                       player_power=pokedex_dict[key3]['attack']+pokedex_dict[key3]['defense']+pokedex_dict[key3]['hp']+pokedex_dict[key3]['special_attack']+pokedex_dict[key3]['special_defense']+pokedex_dict[key3]['speed']
                       print "'player name's power is'", players_dict[key]['player_name'],'power :-' ,player_power

                                
players_power(players,pokedex,1) 
players_power(players,pokedex,2)
# Out:
# whoplayer:  1
# key2 1
# stats:- 100
# key3 1.0
# attack:- 102
# defense:- 103
# 'player name's power is' Ben power :- 621
# key3 1.0
# attack:- 102
# defense:- 103
# 'player name's power is' Ben power :- 621
# whoplayer:  2
# key3 2.0
# attack:- 202
# defense:- 203
# 'player name's power is' Judy power :- 1221
# key2 2
# stats:- 200
# key3 2.0
# attack:- 202
# defense:- 203
# 'player name's power is' Judy power :- 1221

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 8. Load a pokedex file containing all the pokemon
#
# ---
#
# ### 8.1
#
# While you were putting together the prototype code, your colleagues were preparing a dataset of Pokemon and their attributes. (This was a rush job, so they may have picked some crazy values for some...)
#
# The code below loads information from a comma separated value (csv) file. You need to parse this string into a more useable format. The format of the string is:
#
# - Rows are separated by newline characters: \n
# - Columns are separated by commas: ,
# - All cells in the csv are double quoted. Ex: "PokedexNumber" is the first cell of the first row.
#
#
# Using for-loops, create a list of lists where each list within the overall list is a row of the csv/matrix, and each element in that list is a cell in that row. Additional criteria:
#
# 1. Quotes are removed from each cell item.
# 2. Numeric column values are converted to floats.
# 3. There are some cells that are empty and have no information. For these cells put a -1 value in place.
#
# Your end result is effectively a matrix. Each list in the outer list is a row, and the *j*th elements of list together form the *j*th column, which represents a data attribute. The first three lists in your pokedex list should look like this:
#
#     ['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed']
#     [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0]
#     [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0]

# %%
# Code to read in pokedex info

raw_pd = ''
pokedex_file = 'pokedex_basic.csv'
with open(pokedex_file, 'r') as f:
    raw_pd = f.read()
    
    raw_pd
    
# the pokedex string is assigned to the raw_pd variable

# %%
import csv

#file_path = "C:/Users/bless/Documents/GitHub/projects/project-one/pokedex_basic.csv"
#read the file into a string called raw_pd
file_path = "C:/Users/bless/Documents/GitHub/projects/project-one/pokedex_basic.csv"
raw_pd = ''

with open(file_path, 'rU') as f:
    raw_pd = f.read()


# the pokedex string is assigned to the raw_pd variable

# now create the list which stores each row as a list and each column is stored in the respective rows in
# the corresponding cells eg row 1 cell 1 is column1, row1 cell2 is column 2
# All the values in a single column is the  corresponding cells across all rows 

#check format of string     
raw_pd[0:150]
# Out:
# '"PokedexNumber","Name","Type","Total","HP","Attack","Defense","SpecialAttack","SpecialDefense","Speed"\n"001","Bulbasaur","GrassPoison","318","45","49"'

# %%
#create a list using the newline /n char from the string 
newlist=[]
newlist=raw_pd.splitlines()
newlist
# Out:
# ['"PokedexNumber","Name","Type","Total","HP","Attack","Defense","SpecialAttack","SpecialDefense","Speed"',
#  '"001","Bulbasaur","GrassPoison","318","45","49","49","65","65","45"',
#  '"002","Ivysaur","GrassPoison","405","60","62","63","80","80","60"',
#  '"003","Venusaur","GrassPoison","525","80","82","83","100","100","80"',
#  '"003","VenusaurMega Venusaur","GrassPoison","625","80","100","123","122","120","80"',
#  '"004","Charmander","Fire","309","39","52","43","60","50","65"',
#  '"005","Charmeleon","Fire","405","58","64","58","80","65","80"',
#  '"006","Charizard","FireFlying","534","78","84","78","109","85","100"',
#  '"006","CharizardMega Charizard X","FireDragon","634","78","130","111","130","85","100"',
#  '"006","CharizardMega Charizard Y","FireFlying","634","78","104","78","159","115","100"',
#  '"007","Squirtle","Water","314","44","48","65","50","64","43"',
#  '"008","Wartortle","Water","405","59","63","80","65","80","58"',
# ...

# %%
#removing the quotes "" from the list 

newlist33=[]
newlist2 = [i.replace('"', '') for i in newlist] # remove quote from each element
newlist2
# newlist33= [i.replace('', '-1') for i in newlist2] 
newlist33=newlist2
newlist33
# Out:
# ['PokedexNumber,Name,Type,Total,HP,Attack,Defense,SpecialAttack,SpecialDefense,Speed',
#  '001,Bulbasaur,GrassPoison,318,45,49,49,65,65,45',
#  '002,Ivysaur,GrassPoison,405,60,62,63,80,80,60',
#  '003,Venusaur,GrassPoison,525,80,82,83,100,100,80',
#  '003,VenusaurMega Venusaur,GrassPoison,625,80,100,123,122,120,80',
#  '004,Charmander,Fire,309,39,52,43,60,50,65',
#  '005,Charmeleon,Fire,405,58,64,58,80,65,80',
#  '006,Charizard,FireFlying,534,78,84,78,109,85,100',
#  '006,CharizardMega Charizard X,FireDragon,634,78,130,111,130,85,100',
#  '006,CharizardMega Charizard Y,FireFlying,634,78,104,78,159,115,100',
#  '007,Squirtle,Water,314,44,48,65,50,64,43',
#  '008,Wartortle,Water,405,59,63,80,65,80,58',
#  '009,Blastoise,Water,530,79,83,100,85,105,78',
#  '009,BlastoiseMega Blastoise,Water,630,79,103,120,135,115,78',
#  '010,Caterpie,Bug,195,45,30,35,20,20,45',
#  '011,Metapod,Bug,205,50,20,55,25,25,30',
#  '012,Butterfree,BugFlying,395,60,45,50,90,80,70',
# ...

# %%
#create sublists for each list item 
for i in range(0,len(newlist)):
# print  'i and i+1=', i, i+1, newlist2[i:i+1]
   newlist33[i]=newlist33[i:i+1]
     
#newlist2 = [i.replace('"', '') for i in newlist]
newlist33
# Out:
# [['PokedexNumber,Name,Type,Total,HP,Attack,Defense,SpecialAttack,SpecialDefense,Speed'],
#  ['001,Bulbasaur,GrassPoison,318,45,49,49,65,65,45'],
#  ['002,Ivysaur,GrassPoison,405,60,62,63,80,80,60'],
#  ['003,Venusaur,GrassPoison,525,80,82,83,100,100,80'],
#  ['003,VenusaurMega Venusaur,GrassPoison,625,80,100,123,122,120,80'],
#  ['004,Charmander,Fire,309,39,52,43,60,50,65'],
#  ['005,Charmeleon,Fire,405,58,64,58,80,65,80'],
#  ['006,Charizard,FireFlying,534,78,84,78,109,85,100'],
#  ['006,CharizardMega Charizard X,FireDragon,634,78,130,111,130,85,100'],
#  ['006,CharizardMega Charizard Y,FireFlying,634,78,104,78,159,115,100'],
#  ['007,Squirtle,Water,314,44,48,65,50,64,43'],
#  ['008,Wartortle,Water,405,59,63,80,65,80,58'],
#  ['009,Blastoise,Water,530,79,83,100,85,105,78'],
#  ['009,BlastoiseMega Blastoise,Water,630,79,103,120,135,115,78'],
#  ['010,Caterpie,Bug,195,45,30,35,20,20,45'],
#  ['011,Metapod,Bug,205,50,20,55,25,25,30'],
# ...

# %%
#split each list item into sub strings

list6=[]
for i in range(len(newlist33)):
#             print 'i=: ', i, 'newlist33[i][0]', newlist33[i][0].split(',')
              list6.append(newlist33[i][0].split(','))
                                                
print list6
# Out:
# [['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed'], ['001', 'Bulbasaur', 'GrassPoison', '318', '45', '49', '49', '65', '65', '45'], ['002', 'Ivysaur', 'GrassPoison', '405', '60', '62', '63', '80', '80', '60'], ['003', 'Venusaur', 'GrassPoison', '525', '80', '82', '83', '100', '100', '80'], ['003', 'VenusaurMega Venusaur', 'GrassPoison', '625', '80', '100', '123', '122', '120', '80'], ['004', 'Charmander', 'Fire', '309', '39', '52', '43', '60', '50', '65'], ['005', 'Charmeleon', 'Fire', '405', '58', '64', '58', '80', '65', '80'], ['006', 'Charizard', 'FireFlying', '534', '78', '84', '78', '109', '85', '100'], ['006', 'CharizardMega Charizard X', 'FireDragon', '634', '78', '130', '111', '130', '85', '100'], ['006', 'CharizardMega Charizard Y', 'FireFlying', '634', '78', '104', '78', '159', '115', '100'], ['007', 'Squirtle', 'Water', '314', '44', '48', '65', '50', '64', '43'], ['008', 'Wartortle', 'Water', '405', '59', '63'
# ...

# %%
#replace newlist2 with split items
newlist33=list6[:]
print newlist33[0][1:10]
# Out:
# ['Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed']

# %%
#Quotes are removed from each cell item.
#Numeric column values are converted to floats.
#There are some cells that are empty and have no information. For these cells put a -1 value in place.
#['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed']
#[1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0]
#[2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0]

#if (    cond1 == 'val1' and cond2 == 'val2' and
#          cond3 == 'val3' and cond4 == 'val4'):
#      do_something

list9=[]
for i in range(0, len(newlist33)):
        for j in range(10): 
           if (i!=0 and j!= 1 and j!=2):
               convertin=float(newlist33[i][j])
               list9.append(convertin)
           else:
               list9.append(newlist33[i][j])

# print list9   

list10 = [list9[x:x+10] for x in xrange(0, len(list9), 10)]

# print res


print list10
# Out:
# [['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed'], [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0], [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0], [3.0, 'Venusaur', 'GrassPoison', 525.0, 80.0, 82.0, 83.0, 100.0, 100.0, 80.0], [3.0, 'VenusaurMega Venusaur', 'GrassPoison', 625.0, 80.0, 100.0, 123.0, 122.0, 120.0, 80.0], [4.0, 'Charmander', 'Fire', 309.0, 39.0, 52.0, 43.0, 60.0, 50.0, 65.0], [5.0, 'Charmeleon', 'Fire', 405.0, 58.0, 64.0, 58.0, 80.0, 65.0, 80.0], [6.0, 'Charizard', 'FireFlying', 534.0, 78.0, 84.0, 78.0, 109.0, 85.0, 100.0], [6.0, 'CharizardMega Charizard X', 'FireDragon', 634.0, 78.0, 130.0, 111.0, 130.0, 85.0, 100.0], [6.0, 'CharizardMega Charizard Y', 'FireFlying', 634.0, 78.0, 104.0, 78.0, 159.0, 115.0, 100.0], [7.0, 'Squirtle', 'Water', 314.0, 44.0, 48.0, 65.0, 50.0, 64.0, 43.0], [8.0, 'Wartortle', 'Water', 405.0, 59.0, 63.0, 80.0, 65.0, 80.0, 58
# ...

# %%
#replace newlist2 with changed items
newlist33=list10
print newlist33
# Out:
# [['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed'], [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0], [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0], [3.0, 'Venusaur', 'GrassPoison', 525.0, 80.0, 82.0, 83.0, 100.0, 100.0, 80.0], [3.0, 'VenusaurMega Venusaur', 'GrassPoison', 625.0, 80.0, 100.0, 123.0, 122.0, 120.0, 80.0], [4.0, 'Charmander', 'Fire', 309.0, 39.0, 52.0, 43.0, 60.0, 50.0, 65.0], [5.0, 'Charmeleon', 'Fire', 405.0, 58.0, 64.0, 58.0, 80.0, 65.0, 80.0], [6.0, 'Charizard', 'FireFlying', 534.0, 78.0, 84.0, 78.0, 109.0, 85.0, 100.0], [6.0, 'CharizardMega Charizard X', 'FireDragon', 634.0, 78.0, 130.0, 111.0, 130.0, 85.0, 100.0], [6.0, 'CharizardMega Charizard Y', 'FireFlying', 634.0, 78.0, 104.0, 78.0, 159.0, 115.0, 100.0], [7.0, 'Squirtle', 'Water', 314.0, 44.0, 48.0, 65.0, 50.0, 64.0, 43.0], [8.0, 'Wartortle', 'Water', 405.0, 59.0, 63.0, 80.0, 65.0, 80.0, 58
# ...

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 8.2 Parse the raw pokedex with list comprehensions
#
# ---
#
# Perform the same parsing as above, but **using only a single list comprehension** instead of for loops. You may have nested list comprehensions within the main list comprehension! The output should be exactly the same.

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 9. Write a function to generate the full pokedex
#
# ---
#
# Write a function that recreates the pokedex you made before, but with the data read in from the full pokemon file. The `PokedexNumber` should be used as the `pokemon_id` key values for the dictionary of pokemon.
#
# Your function should:
#
# 1. Take the parsed pokedex information you created above as an argument.
# 2. Return a dictionary in the same format as your original pokedex you created before containing the information from the parsed full pokedex file.
#
# To test the function, print out the pokemon with id = 100.

# %%
#read in the podex file into a dictionary  
newpodexdict={}

for i in range(0, len(newlist33)):
           newpodexdict[i]=newlist33[i]

print newpodexdict
# Out:
# {0: ['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed'], 1: [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0], 2: [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0], 3: [3.0, 'Venusaur', 'GrassPoison', 525.0, 80.0, 82.0, 83.0, 100.0, 100.0, 80.0], 4: [3.0, 'VenusaurMega Venusaur', 'GrassPoison', 625.0, 80.0, 100.0, 123.0, 122.0, 120.0, 80.0], 5: [4.0, 'Charmander', 'Fire', 309.0, 39.0, 52.0, 43.0, 60.0, 50.0, 65.0], 6: [5.0, 'Charmeleon', 'Fire', 405.0, 58.0, 64.0, 58.0, 80.0, 65.0, 80.0], 7: [6.0, 'Charizard', 'FireFlying', 534.0, 78.0, 84.0, 78.0, 109.0, 85.0, 100.0], 8: [6.0, 'CharizardMega Charizard X', 'FireDragon', 634.0, 78.0, 130.0, 111.0, 130.0, 85.0, 100.0], 9: [6.0, 'CharizardMega Charizard Y', 'FireFlying', 634.0, 78.0, 104.0, 78.0, 159.0, 115.0, 100.0], 10: [7.0, 'Squirtle', 'Water', 314.0, 44.0, 48.0, 65.0, 50.0, 64.0, 43.0], 11: [8.0, 'Wartortle', 'Water', 4
# ...

# %%
#recreate the pokedex file using the data from the parsed data file 
updatedict1={}

#key=1
#print newpodexdict[key][0],newpodexdict[key][3]

for key,val in newpodexdict.items():
#     print key
     if key != 0 :
#fill in the data form the parsed file 
        dictkey=[val][0][0]
#        print dictkey
        updatedict1[dictkey]={'pokedexnumber':val[0],'name':val[1],'type':val[2],'total':val[3],'hp':val[4],'attack':val[5],'defense':val[6],'special_attack':val[7],'special_defense':val[8],'speed':val[9]}
                                  
newpodexdict2=updatedict1   

print newpodexdict2   

# print 'pokemon-id=100 ',newpodexdict2[100]
# Out:
# {1.0: {'attack': 49.0, 'defense': 49.0, 'pokedexnumber': 1.0, 'name': 'Bulbasaur', 'special_attack': 65.0, 'speed': 45.0, 'hp': 45.0, 'total': 318.0, 'type': 'GrassPoison', 'special_defense': 65.0}, 2.0: {'attack': 62.0, 'defense': 63.0, 'pokedexnumber': 2.0, 'name': 'Ivysaur', 'special_attack': 80.0, 'speed': 60.0, 'hp': 60.0, 'total': 405.0, 'type': 'GrassPoison', 'special_defense': 80.0}, 3.0: {'attack': 100.0, 'defense': 123.0, 'pokedexnumber': 3.0, 'name': 'VenusaurMega Venusaur', 'special_attack': 122.0, 'speed': 80.0, 'hp': 80.0, 'total': 625.0, 'type': 'GrassPoison', 'special_defense': 120.0}, 4.0: {'attack': 52.0, 'defense': 43.0, 'pokedexnumber': 4.0, 'name': 'Charmander', 'special_attack': 60.0, 'speed': 65.0, 'hp': 39.0, 'total': 309.0, 'type': 'Fire', 'special_defense': 50.0}, 5.0: {'attack': 64.0, 'defense': 58.0, 'pokedexnumber': 5.0, 'name': 'Charmeleon', 'special_attack': 80.0, 'speed': 80.0, 'hp': 58.0, 'total': 405.0, 'type': 'Fire', 'special_defense': 65.0}, 6.0: 
# ...

# %%
newlist2
# Out:
# [['PokedexNumber,Name,Type,Total,HP,Attack,Defense,SpecialAttack,SpecialDefense,Speed'],
#  ['001,Bulbasaur,GrassPoison,318,45,49,49,65,65,45'],
#  ['002,Ivysaur,GrassPoison,405,60,62,63,80,80,60'],
#  ['003,Venusaur,GrassPoison,525,80,82,83,100,100,80'],
#  ['003,VenusaurMega Venusaur,GrassPoison,625,80,100,123,122,120,80'],
#  ['004,Charmander,Fire,309,39,52,43,60,50,65'],
#  ['005,Charmeleon,Fire,405,58,64,58,80,65,80'],
#  ['006,Charizard,FireFlying,534,78,84,78,109,85,100'],
#  ['006,CharizardMega Charizard X,FireDragon,634,78,130,111,130,85,100'],
#  ['006,CharizardMega Charizard Y,FireFlying,634,78,104,78,159,115,100'],
#  ['007,Squirtle,Water,314,44,48,65,50,64,43'],
#  ['008,Wartortle,Water,405,59,63,80,65,80,58'],
#  ['009,Blastoise,Water,530,79,83,100,85,105,78'],
#  ['009,BlastoiseMega Blastoise,Water,630,79,103,120,135,115,78'],
#  ['010,Caterpie,Bug,195,45,30,35,20,20,45'],
#  ['011,Metapod,Bug,205,50,20,55,25,25,30'],
# ...

# %%
#Write a function that recreates the pokedex you made before, but with the data read in from the full pokemon file. The PokedexNumber should be used as the pokemon_id key values for the dictionary of pokemon.

#Your function should:

# pokemonid = 100 {100.0: {'attack': 30.0, 'defense': 50.0, 'pokedexnumber': 100.0, 
#   'name': 'Voltorb', 'special_attack': 55.0, 'speed': 100.0, 'hp': 40.0, 
#   'total': 330.0, 'type': 'Electric', 'special_defense': 55.0}, 101.0: {'attack': 50.0, 'defense': 70.0, 'pokedexnumber':

#Take the parsed pokedex information you created above as an argument.
#Return a dictionary in the same format as your original pokedex you created before containing the information from the parsed full pokedex file.
#To test the function, print out the pokemon with id = 100.

def generate_pokedex(pokedex,pokemon_num):
    pokedex_dicttemp={}
    
#read in the podex file into a dictionary  
    newpodexdictemp={}
    updatedict1temp={}
#     print pokedex
    for i in range(0, len(pokedex)):
           newpodexdictemp[i]=pokedex[i]
#     print newpodexdicttemp 
    
    
    for key,value in newpodexdictemp.items():
            value=value[0].split(',')
#             print key,value 
#recreate the pokedex file using the data from the parsed data file 
            

            if key != 0 :
#  fill in the data form the parsed file 
# #             print dictkey
                updatedict1temp[key]={'pokedexnumber':value[0],'name':value[1],'type':value[2],'total':value[3],'hp':value[4],'attack':value[5],'defense':value[6],'special_attack':value[7],'special_defense':value[8],'speed':value[9]}
            
#             print updatedict1temp
        
                            

    for key1,value1 in updatedict1temp.items():
#         print key1,value1
        if pokemon_num==" ":
            return updatedict1temp
              
        else:
#             print value1['pokedexnumber'],pokemon_num
            if pokemon_num==value1['pokedexnumber']:
                return value1    
            
generate_pokedex(newlist2,'100')

# print generate_pokedex(newlist2)
# Out:
# {'attack': '30',
#  'defense': '50',
#  'hp': '40',
#  'name': 'Voltorb',
#  'pokedexnumber': '100',
#  'special_attack': '55',
#  'special_defense': '55',
#  'speed': '100',
#  'total': '330',
#  'type': 'Electric'}

# %% [markdown]
# <img src="http://i.imgur.com/GCAf1UX.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 10. Write a function to generate a "filtered" pokedex
# ---
# Your function should:
# 1. Take the parsed pokedex information you created above as an argument.
# 1. Take a dictionary as a parameter with keys matching the features of the Pokedex, filtering by exact match for string type values, and/or filter continuous variables specified value that is greater than or equal to the dictionary key parameter.
# 1. Return multiple elements from the Pokedex
#
# Example:
#
# ```python
#
# # Only filter based on parameters passed
# filter_options = {
#     'Attack':   25,
#     'Defense':  30,
#     'Type':     'Electric'
# }
#
# # Return records with attack >= 24, defense >= 30, and type == "Electric"
# # Also anticipate that other paramters can also be passed such as "SpecialAttack", "Speed", etc.
# filtered_pokedex(pokedex_data, filter=filter_options)
#
# # Example output:
# # [{'Attack': 30.0,
# #  'Defense': 50.0,
# #  'HP': 40.0,
# #  'Name': 'Voltorb',
# #  'SpecialAttack': 55.0,
# #  'SpecialDefense': 55.0,
# #  'Speed': 100.0,
# #  'Total': 330.0,
# #  'Type': 'Electric'},
# #  {'Attack': 30.0,
# #  'Defense': 33.0,
# #  'HP': 32.0,
# #  'Name': 'Pikachu',
# #  'SpecialAttack': 55.0,
# #  'SpecialDefense': 55.0,
# #  'Speed': 100.0,
# #  'Total': 330.0,
# #  'Type': 'Electric'},
# #  ... etc
# #  ]
#
# ```

# %%
fullpodexfiledict=generate_pokedex(newlist2,' ')
print fullpodexfiledict
# Out:
# {1: {'attack': '49', 'defense': '49', 'pokedexnumber': '001', 'name': 'Bulbasaur', 'special_attack': '65', 'speed': '45', 'hp': '45', 'total': '318', 'type': 'GrassPoison', 'special_defense': '65'}, 2: {'attack': '62', 'defense': '63', 'pokedexnumber': '002', 'name': 'Ivysaur', 'special_attack': '80', 'speed': '60', 'hp': '60', 'total': '405', 'type': 'GrassPoison', 'special_defense': '80'}, 3: {'attack': '82', 'defense': '83', 'pokedexnumber': '003', 'name': 'Venusaur', 'special_attack': '100', 'speed': '80', 'hp': '80', 'total': '525', 'type': 'GrassPoison', 'special_defense': '100'}, 4: {'attack': '100', 'defense': '123', 'pokedexnumber': '003', 'name': 'VenusaurMega Venusaur', 'special_attack': '122', 'speed': '80', 'hp': '80', 'total': '625', 'type': 'GrassPoison', 'special_defense': '120'}, 5: {'attack': '52', 'defense': '43', 'pokedexnumber': '004', 'name': 'Charmander', 'special_attack': '60', 'speed': '65', 'hp': '39', 'total': '309', 'type': 'Fire', 'special_defense': '50'}
# ...

# %%
#Take the parsed pokedex information you created above as an argument.
#Take a dictionary as a parameter with keys matching the features of the Pokedex, filtering by exact match for string type values, and/or filter continuous variables specified value that is greater than or equal to the dictionary key parameter.
#Return multiple elements from the Pokedex
#Example:
# Only filter based on parameters passed
# filter_options = {
#    'Attack':   25,
#    'Defense':  30,
#    'Type':     'Electric'
#   }


# #def filter_pokedex(dictionary,paradict)

# paradict={}
# paradict['attack']= 25
# paradict['defense']=30
# paradict['type']='Electric'

# #for  in newpodexdict2() :   

# # get the full podexfile  by generating it 
# # fullpodexfiledict=generate_pokedex(newlist2,' ')

# for key2,value2 in fullpodxefiledict.items():
#     for key3,value3 in paradict.items():
#          if key3 in value2:
#                 paradict[key3]==
#         if newpodexdict2[k] == paradict[k]:
#             print "Key and value bot matches in both ", k

# #for key,val in newpodexdict2.items():

#     print key,val
        
#        for eachkey in val in paradict:
#            if newpodxdict2.items()[eachkey] == val[0]:
#                print 'key, eachkey,val:',key,eachkey,val
#        print dictkey
#            updatedict1temp[dictkey]={'pokedexnumber':val[0],'name':val[1],'type':val[2],'total':val[3],'hp':val[4],'attack':val[5],'defense':val[6],'special_attack':val[7],'special_defense':val[8],'speed':val[9]}
                                  
#    outputdict=updatedict1temp

# %% [markdown]
# ## 9. Descriptive statistics on the prototype pokedex
#
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
# ### 9.1
#
# What is the population mean and standard deviation of the "Total" attribute for all characters in the Pokedex?

# %%
sampletotal=[]
meansandsd={}
for key, value in newpodexdict2.items():
#     print 'Key ', key
    temp=value['total'] 
    sampletotal.append(temp)
    
sampletotal

from scipy import stats
import numpy as np 

#
X=sampletotal 
#    print 'col :' , col1
#    print data
#    modeval=stats.mode((data[col])
                       
print 'Mean of Total is :', np.mean(X), '& Standard Deviation is: ', np.std(X)


meansandsd['mean']=np.mean(X)
meansandsd['SD']=np.std(X)

print meansandsd
#, str(np.median(X)), str(np.var(X)), str(np.std(X)), str(stats.mode([round(d,2) for d in X]))
#    print('Mean : '.format(np.mean(X))), np.mean(X)
    
#   print np.mean(data[col]), np.median(data[col]), np.var(data[col]), np.std(data[col]), stats.mode(data[col])
# Out:
# Mean of Total is : 424.950069348 & Standard Deviation is:  118.711775818
# {'SD': 118.71177581751657, 'mean': 424.95006934812761}

# %%
#def a function to get totals  for each podexnumber

def computetot(inputkey):

    sampletotal=[]
    for key, value in newpodexdict2.items():
#         print 'Key ', key, 'inputkey',inputkey
        if key == inputkey: 
            temp=value['total'] 
            sampletotal.append(temp)
    
    return sampletotal

# computetot(1.0)

totlist=[]

for key,val in newpodexdict2.items():
#     meanslist=[key]
#         print 'key=', key, 'Mean=', computemeans(key)
#     print key, computetot(key)
    totlist.append([key,computetot(key)])
    
totlist
# Out:
# [[1.0, [318.0]],
#  [2.0, [405.0]],
#  [3.0, [625.0]],
#  [4.0, [309.0]],
#  [5.0, [405.0]],
#  [6.0, [634.0]],
#  [7.0, [314.0]],
#  [8.0, [405.0]],
#  [9.0, [630.0]],
#  [10.0, [195.0]],
#  [11.0, [205.0]],
#  [12.0, [395.0]],
#  [13.0, [195.0]],
#  [14.0, [205.0]],
#  [15.0, [495.0]],
#  [16.0, [251.0]],
#  [17.0, [349.0]],
#  [18.0, [579.0]],
#  [19.0, [253.0]],
#  [20.0, [413.0]],
#  [21.0, [262.0]],
#  [22.0, [442.0]],
#  [23.0, [288.0]],
#  [24.0, [438.0]],
#  [25.0, [320.0]],
#  [26.0, [485.0]],
#  [27.0, [300.0]],
#  [28.0, [450.0]],
#  [29.0, [275.0]],
#  [30.0, [365.0]],
#  [31.0, [505.0]],
#  [32.0, [273.0]],
#  [33.0, [365.0]],
#  [34.0, [505.0]],
#  [35.0, [323.0]],
#  [36.0, [483.0]],
#  [37.0, [299.0]],
#  [38.0, [505.0]],
#  [39.0, [270.0]],
#  [40.0, [435.0]],
#  [41.0, [245.0]],
#  [42.0, [455.0]],
#  [43.0, [320.0]],
#  [44.0, [395.0]],
#  [45.0, [490.0]],
#  [46.0, [285.0]],
#  [47.0, [405.0]],
#  [48.0, [305.0]],
#  [49.0, [450.0]],
#  [50.0, [265.0]],
# ...

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
# ### 9.2
#
# The game is no fun if the characters are wildly unbalanced! Are any characters "overpowered", which we'll define as having a "Total" more than three standard deviations from the population mean?

# %%
meansandsd
# Out:
# {'SD': 118.71177581751657, 'mean': 424.95006934812761}

# %%
round(3*meansandsd['SD'])
# Out:
# 356.0

# %%
# check if each total is Greater than 3 SD of Total mean 

# meansandsd
# totlist

for key,value in totlist:
#     print key,value
    total=meansandsd['mean']+round(3*meansandsd['SD'],0)
#     print total
    if value[0] > total:
          print "overpowered" , key ,value[0] ,total

# %%
# newpodexdict2.items()

# %%
# newpodexdict2
# sampledict={}
# for key, value in newpodexdict2.items():
# #     print key, value
# #     sampledict={}
# #     sampledict[key]='test'
# #     print sampledict
#     samplelist=[]
# #     keyval=str(key)
# #     sampletotal.append(key)
# #    samplelist.append(key)
#     for key1,value1 in value.items():
        
# #          print key1, value1
# #             if key1 == 'total' or key1 == 'defense':
#         if key1=='total':

#             samplelist.append(value1)
# #             print samplelist
#         sampledict[key]=samplelist

# sampledict

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 10. Calibrate the frequency of Pokemon
#
# The design team wants you to make the powerful Pokemon rare, and the weaklings more common. How would you set the probability $p_i$ of finding Pokemon *i* each time a player visits a gym?
#
# Write a function that takes in a Pokedex number and returns a value $p_i$ for that character.
#
# Hint: there are many ways you could do this. What do _you_ think makes sense? Start with simplifying assumptions: for example, you could assume that the probabilities of encountering any two Pokemon on one visit to a gym are independent of each other.

# %%
P(A and B) = P(A) * P(B)
